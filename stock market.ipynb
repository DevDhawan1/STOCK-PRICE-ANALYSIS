# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import pandas_datareader.data as web
import datetime
import yfinance as yf

# %%
start = datetime.datetime(2015, 6, 4)
end = datetime.datetime(2025, 6, 4)

# %%
jpm = yf.download('JPM', start, end)
jpm.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker            JPM        JPM        JPM        JPM       JPM
# Date
# 2015-06-04  50.405933  50.953081  50.162757  50.390732  13863300
# 2015-06-05  51.234253  51.553421  50.922686  51.196260  20801100
# 2015-06-08  50.831482  51.333036  50.770686  51.264640  14558700
# 2015-06-09  51.051868  51.120259  50.512321  50.877083  13263500
# 2015-06-10  51.872581  52.054962  51.272239  51.363426  17478900

# %%
netflix = yf.download('NFLX', start, end)
netflix.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           NFLX       NFLX       NFLX       NFLX      NFLX
# Date
# 2015-06-04  89.348572  89.428574  88.042854  88.378571  10074400
# 2015-06-05  90.459999  90.540001  89.125717  89.214287  11624200
# 2015-06-08  89.604286  90.815712  88.995712  90.714287  11148900
# 2015-06-09  92.449997  92.714287  89.334290  89.334290  22024800
# 2015-06-10  95.871429  98.970001  93.225716  93.395714  57121400

# %%
tesla = yf.download('TSLA', start, end)
tesla.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           TSLA       TSLA       TSLA       TSLA      TSLA
# Date
# 2015-06-04  16.394667  16.620001  16.380667  16.500000  36804000
# 2015-06-05  16.609333  16.646667  16.378668  16.400000  45330000
# 2015-06-08  17.086000  17.250000  16.687332  16.723333  75255000
# 2015-06-09  17.066668  17.182667  16.942667  17.026667  39166500
# 2015-06-10  16.713333  16.933332  16.566668  16.793333  51817500

# %%
apple = yf.download('AAPL', start, end)
apple.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-06-04  28.972351  29.245591  28.871567  29.021624  153800400
# 2015-06-05  28.813335  29.046263  28.748387  29.003709  142507200
# 2015-06-08  28.622969  28.938763  28.405721  28.869330  210699200
# 2015-06-09  28.537849  28.685668  28.134710  28.376593  224301600
# 2015-06-10  28.864849  28.967872  28.634162  28.649839  156349200

# %%
jpm.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker          JPM          JPM          JPM          JPM           JPM
# count   2515.000000  2515.000000  2515.000000  2515.000000  2.515000e+03
# mean     113.692716   114.745198   112.589587   113.651704  1.368988e+07
# std       52.053210    52.513934    51.528393    51.989790  6.496789e+06
# min       41.160065    41.811553    38.298219    41.803798  3.220500e+06
# 25%       78.965816    79.839468    78.036832    78.893333  9.347350e+06
# 50%       98.669586   100.008043    97.612018    98.865200  1.228310e+07
# 75%      138.837105   139.961106   137.569540   138.740465  1.596755e+07
# max      278.236206   278.534375   275.522925   276.973965  5.619230e+07

# %%
jpm.columns = jpm.columns.get_level_values(0)

# %%
jpm.isna().sum()
# Out:
# Price
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
jpm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2515 entries, 2015-06-04 to 2025-06-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
#  1   High    2515 non-null   float64
#  2   Low     2515 non-null   float64
#  3   Open    2515 non-null   float64
#  4   Volume  2515 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 117.9 KB

# %%
netflix.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker         NFLX         NFLX         NFLX         NFLX          NFLX
# count   2515.000000  2515.000000  2515.000000  2515.000000  2.515000e+03
# mean     374.882136   380.251678   369.148857   374.686203  8.391980e+06
# std      224.981499   227.531013   222.046284   224.609062  7.421263e+06
# min       82.790001    84.699997    79.949997    80.570000  1.144000e+06
# 25%      187.794998   189.945000   184.665001   187.439995  4.061650e+06
# 50%      348.410004   354.000000   342.440002   348.109985  6.181800e+06
# 75%      501.214996   507.755005   493.895004   501.720001  9.920250e+06
# max     1218.979980  1229.569946  1211.180054  1219.869995  1.333875e+08

# %%
netflix.columns = netflix.columns.get_level_values(0)

# %%
netflix.isna().sum()
# Out:
# Price
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2515 entries, 2015-06-04 to 2025-06-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
#  1   High    2515 non-null   float64
#  2   Low     2515 non-null   float64
#  3   Open    2515 non-null   float64
#  4   Volume  2515 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 117.9 KB

# %%
apple.describe()
apple.columns = apple.columns.get_level_values(0)

# %%
apple.isna().sum()
# Out:
# Price
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2515 entries, 2015-06-04 to 2025-06-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
#  1   High    2515 non-null   float64
#  2   Low     2515 non-null   float64
#  3   Open    2515 non-null   float64
#  4   Volume  2515 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 117.9 KB

# %%
tesla.describe()
tesla.columns = tesla.columns.get_level_values(0)

# %%
tesla.isna().sum()
# Out:
# Price
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2515 entries, 2015-06-04 to 2025-06-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
#  1   High    2515 non-null   float64
#  2   Low     2515 non-null   float64
#  3   Open    2515 non-null   float64
#  4   Volume  2515 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 117.9 KB

# %%
fig = px.histogram(jpm, 
                   x='Close', 
                   marginal='box', 
                   nbins=47, 
                   title='Distribution of Close')
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.histogram(jpm, 
                   x='Open', 
                   marginal='box', 
                   color_discrete_sequence=['red'], 
                   title='Distribution of open')
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.scatter(jpm, 
                 x='Open', 
                 y='Close', 
                 
                 opacity=0.8, 
                  
                 title='Open vs. Close')
fig.update_traces(marker_size=5)
fig.show()

# %%
jpm.corr()
# Out:
# Price      Close      High       Low      Open    Volume
# Price
# Close   1.000000  0.999784  0.999766  0.999529 -0.362755
# High    0.999784  1.000000  0.999647  0.999759 -0.355120
# Low     0.999766  0.999647  1.000000  0.999753 -0.369517
# Open    0.999529  0.999759  0.999753  1.000000 -0.361396
# Volume -0.362755 -0.355120 -0.369517 -0.361396  1.000000

# %%
jpm['2015':'2025'].plot(subplots=True, figsize=(10,12))
plt.title('JP Morgan & Chase Co stock attributes from 2015 to 2025')
plt.show()

# %%
netflix['2015':'2025'].plot(subplots=True, figsize=(10,12))
plt.title('Netflix stock attributes from 2015 to 2025')
plt.show()

# %%
tesla['2015':'2025'].plot(subplots=True, figsize=(10,12))
plt.title('Tesla stock attributes from 2015 to 2025')
plt.show()

# %%
apple['2015':'2025'].plot(subplots=True, figsize=(10,12))
plt.title('Apple stock attributes from 2015 to 2025')
plt.show()

# %%
jpm.High.plot()
netflix.High.plot()
tesla.High.plot()
apple.High.plot()
plt.legend(['JP Morgan & Chase Co', 'Netflix', 'Tesla', 'Apple'])
plt.show()

# %%
normalized_jpm = jpm.High.div(jpm.High.iloc[0]).mul(100)
normalized_netflix = netflix.High.div(netflix.High.iloc[0]).mul(100)
normalized_apple = apple.High.div(apple.High.iloc[0]).mul(100)
normalized_tesla = tesla.High.div(tesla.High.iloc[0]).mul(100)
normalized_jpm.plot()
normalized_netflix.plot()
normalized_apple.plot()
normalized_tesla.plot()
plt.legend(['JP Morgan & Chase Co', 'Netflix', 'Tesla', 'Apple'])
plt.show()

# %%
jpm_mean = jpm.High.expanding().mean()
jpm_std = jpm.High.expanding().std()
jpm.High.plot()
jpm_mean.plot()
jpm_std.plot()
plt.legend(['High','Expanding Mean','Expanding Standard Deviation'])
plt.title('JP Morgan & Chase Co')
plt.show()

# %%
netflix_mean = netflix.High.expanding().mean()
netflix_std = netflix.High.expanding().std()
netflix.High.plot()
netflix_mean.plot()
netflix_std.plot()
plt.legend(['High','Expanding Mean','Expanding Standard Deviation'])
plt.title('Netflix')
plt.show()

# %%
apple_mean = apple.High.expanding().mean()
apple_std = apple.High.expanding().std()
apple.High.plot()
apple_mean.plot()
apple_std.plot()
plt.legend(['High','Expanding Mean','Expanding Standard Deviation'])
plt.title('Apple')
plt.show()

# %%
tesla_mean = tesla.High.expanding().mean()
tesla_std = tesla.High.expanding().std()
tesla.High.plot()
tesla_mean.plot()
tesla_std.plot()
plt.legend(['High','Expanding Mean','Expanding Standard Deviation'])
plt.title('Tesla')
plt.show()

# %%
from pylab import rcParams
import statsmodels.api as sm

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_jpm_volume = sm.tsa.seasonal_decompose(jpm["High"],period=360)
figure = decomposed_jpm_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for JPM', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_netflix_volume = sm.tsa.seasonal_decompose(netflix["High"],period=360)
figure = decomposed_netflix_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for Netflix', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_apple_volume = sm.tsa.seasonal_decompose(apple["High"],period=360)
figure = decomposed_apple_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for Apple', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_tesla_volume = sm.tsa.seasonal_decompose(tesla["High"],period=360)
figure = decomposed_tesla_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for Tesla', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_jpm_volume = sm.tsa.seasonal_decompose(jpm["Close"],period=360)
figure = decomposed_jpm_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for JPM', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_netflix_volume = sm.tsa.seasonal_decompose(netflix["Close"],period=360)
figure = decomposed_netflix_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for Netflix', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_apple_volume = sm.tsa.seasonal_decompose(apple["Close"],period=360)
figure = decomposed_apple_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for Apple', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_tesla_volume = sm.tsa.seasonal_decompose(tesla["Close"],period=360)
figure = decomposed_tesla_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for Tesla', fontsize=16, y=1.02)
plt.show()

# %%
data_jpm = jpm.sort_values(['Date'])
data_jpm.head()
# Out:
# Price           Close       High        Low       Open    Volume
# Date
# 2015-06-04  50.405933  50.953081  50.162757  50.390732  13863300
# 2015-06-05  51.234253  51.553421  50.922686  51.196260  20801100
# 2015-06-08  50.831482  51.333036  50.770686  51.264640  14558700
# 2015-06-09  51.051868  51.120259  50.512321  50.877083  13263500
# 2015-06-10  51.872581  52.054962  51.272239  51.363426  17478900

# %%
jpm_with_date = jpm.reset_index()
print(jpm_with_date.head())
# Out:
# Price       Date      Close       High        Low       Open    Volume
# 0     2015-06-04  50.405933  50.953081  50.162757  50.390732  13863300
# 1     2015-06-05  51.234253  51.553421  50.922686  51.196260  20801100
# 2     2015-06-08  50.831482  51.333036  50.770686  51.264640  14558700
# 3     2015-06-09  51.051868  51.120259  50.512321  50.877083  13263500
# 4     2015-06-10  51.872581  52.054962  51.272239  51.363426  17478900

# %%
data_jpm = jpm_with_date.sort_values(['Date'])
sns.set_style("darkgrid")
plt.figure(figsize = (15,9))
plt.plot(data_jpm[['Close']])
plt.xticks(range(0,data_jpm.shape[0],500),data_jpm['Date'].loc[::500],rotation=45)
plt.title("JPM Stock Price",fontsize=18, fontweight='bold')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price (USD)',fontsize=18)
plt.show()

# %%
netflix_with_date = netflix.reset_index()
data_netflix = netflix_with_date.sort_values(['Date'])
sns.set_style("darkgrid")
plt.figure(figsize = (15,9))
plt.plot(data_netflix[['Close']])
plt.xticks(range(0,data_netflix.shape[0],500),data_netflix['Date'].loc[::500],rotation=45)
plt.title("Netflix Stock Price",fontsize=18, fontweight='bold')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price (USD)',fontsize=18)
plt.show()

# %%
apple_with_date = apple.reset_index()
data_apple = apple_with_date.sort_values(['Date'])
sns.set_style("darkgrid")
plt.figure(figsize = (15,9))
plt.plot(data_apple[['Close']])
plt.xticks(range(0,data_apple.shape[0],500),data_apple['Date'].loc[::500],rotation=45)
plt.title("Apple Stock Price",fontsize=18, fontweight='bold')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price (USD)',fontsize=18)
plt.show()

# %%
tesla_with_data = tesla.reset_index()
data_tesla = tesla_with_data.sort_values(['Date'])
sns.set_style("darkgrid")
plt.figure(figsize = (15,9))
plt.plot(data_tesla[['Close']])
plt.xticks(range(0,data_tesla.shape[0],500),data_tesla['Date'].loc[::500],rotation=45)
plt.title("Tesla Stock Price",fontsize=18, fontweight='bold')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price (USD)',fontsize=18)
plt.show()

# %%
price_jpm = data_jpm[['Close']]
price_jpm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
# dtypes: float64(1)
# memory usage: 19.8 KB

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
price_jpm = data_jpm[['Close']].copy()
scaler = MinMaxScaler(feature_range=(-1,1))
price_jpm['Close'] = scaler.fit_transform(price_jpm['Close'].values.reshape(-1,1))

# %%
def split_data(stock, lookback):
    data_raw = stock.to_numpy()
    data = []

    for index in range(len(data_raw) - lookback):
        data.append(data_raw[index: index + lookback])

    data = np.array(data)
    test_set_size = int(np.round(0.2*data.shape[0]))
    train_set_size = data.shape[0] - (test_set_size)

    x_train = data[:train_set_size,:-1,:]
    y_train = data[:train_set_size,-1,:]

    x_test = data[train_set_size:,:-1]
    y_test = data[train_set_size:,-1,:]

    return [x_train, y_train, x_test, y_test]

# %%
lookback = 20
x_train, y_train, x_test, y_test = split_data(price_jpm, lookback)
print("x_train.shape = ",x_train.shape)
print("x_test.shape= ",x_test.shape)
print("y_train.shape = ",y_train.shape)
print("y_test.shape= ",y_test.shape)
# Out:
# x_train.shape =  (1996, 19, 1)
# x_test.shape=  (499, 19, 1)
# y_train.shape =  (1996, 1)
# y_test.shape=  (499, 1)

# %%
import torch
import torch.nn as nn

# %%
x_train = torch.from_numpy(x_train).type(torch.Tensor)
y_train_gru = torch.from_numpy(y_train).type(torch.Tensor)
x_test = torch.from_numpy(x_test).type(torch.Tensor)
y_test_gru = torch.from_numpy(y_test).type(torch.Tensor)

# %%
input_dim = 1
hidden_dim = 32
num_layers = 2
output_dim = 1
num_epochs = 105

# %%
class GRU(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(GRU, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        
        self.gru = nn.GRU(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()
        out, (hn) = self.gru(x, (h0.detach()))
        out = self.fc(out[:, -1, :]) 
        return out

# %%
model = GRU(input_dim, hidden_dim,output_dim, num_layers)
criterion = torch.nn.MSELoss(reduction='mean')
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
import time
hist = np.zeros(num_epochs)
start_time = time.time()
gru = []

for t in range(num_epochs):
    y_train_pred = model(x_train)

    loss = criterion(y_train_pred, y_train_gru)
    print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()

    optimiser.zero_grad()
    loss.backward()
    optimiser.step()

training_time = time.time()-start_time    
print("Training time: {}".format(training_time))
# Out:
# c:\Users\Devansh Dhawan\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning:
#
# Using a target size (torch.Size([1996, 1])) that is different to the input size (torch.Size([1996, 2])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#
# Epoch  68 MSE:  0.00023852605954743922
# Epoch  69 MSE:  0.00023834744933992624
# Epoch  70 MSE:  0.00023817211331333965
# Epoch  71 MSE:  0.0002379991055931896
# Epoch  72 MSE:  0.00023782765492796898
# Epoch  73 MSE:  0.00023765841615386307
# Epoch  74 MSE:  0.00023749195679556578
# Epoch  75 MSE:  0.0002373277093283832
# Epoch  76 MSE:  0.0002371652371948585
# Epoch  77 MSE:  0.00023700518067926168
# Epoch  78 MSE:  0.0002368473942624405
# Epoch  79 MSE:  0.00023669132497161627
# Epoch  80 MSE:  0.0002365369291510433
# Epoch  81 MSE:  0.00023638454149477184
# Epoch  82 MSE:  0.00023623427841812372
# Epoch  83 MSE:  0.0002360856015002355
# Epoch  84 MSE:  0.00023593880177941173
# Epoch  85 MSE:  0.00023579395201522857
# Epoch  86 MSE:  0.00023565093579236418
# Epoch  87 MSE:  0.00023550944752059877
# Epoch  88 MSE:  0.0002353697782382369
# Epoch  89 MSE:  0.00023523192794527858
# Epoch  90 MSE:  0.0002350957947783172
# Epoch  91 MSE:  0.0002349612332182005
# Epoch  92 MSE:  0.0002348283160245046
# Epoch  93 MSE:  0.00023469705774914473
# Epoch  94 MSE:  0.00023456734197679907
# Epoch  95 MSE:  0.00023443903774023056
# Epoch  96 MSE:  0.00023431239242199808
# Epoch  97 MSE:  0.00023418720229528844
# Epoch  98 MSE:  0.0002340634528081864
# Epoch  99 MSE:  0.00023394115851260722
# Epoch  100 MSE:  0.00023382027575280517
# Epoch  101 MSE:  0.00023370080452878028
# Epoch  102 MSE:  0.00023358264297712594
# Epoch  103 MSE:  0.00023346590751316398
# Epoch  104 MSE:  0.00023335052537731826
# Training time: 11.153520584106445

# %%
predict = pd.DataFrame(scaler.inverse_transform(y_train_pred.detach().numpy()))
original = pd.DataFrame(scaler.inverse_transform(y_train_gru.detach().numpy()))

# %%
import seaborn as sns
sns.set_style("darkgrid")    

fig = plt.figure()
fig.subplots_adjust(hspace=0.2, wspace=0.2)

plt.subplot(1, 2, 1)
ax = sns.lineplot(x = original.index, y = original[0], label="Data", color='royalblue')
ax = sns.lineplot(x = predict.index, y = predict[0], label="Training Prediction (GRU)", color='tomato')
ax.set_title('Amazon stock price', size = 14, fontweight='bold')
ax.set_xlabel("Days", size = 14)
ax.set_ylabel("Cost (USD)", size = 14)
ax.set_xticklabels('', size=10)


plt.subplot(1, 2, 2)
ax = sns.lineplot(data=hist, color='royalblue')
ax.set_xlabel("Epoch", size = 14)
ax.set_ylabel("Loss", size = 14)
ax.set_title("Training Loss", size = 14, fontweight='bold')
fig.set_figheight(6)
fig.set_figwidth(16)

# %%
import math, time
from sklearn.metrics import mean_squared_error
y_test_pred = model(x_test)

# invert predictions
y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
y_train = scaler.inverse_transform(y_train_gru.detach().numpy())
y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy())
y_test = scaler.inverse_transform(y_test_gru.detach().numpy())

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[:,0], y_test_pred[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
gru.append(trainScore)
gru.append(testScore)
gru.append(training_time)
# Out:
# Train Score: 1.83 RMSE
# Test Score: 8.79 RMSE

# %%
trainPredictPlot = np.empty_like(price_jpm)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[lookback:len(y_train_pred)+lookback, :] = y_train_pred[:, [0]]

testPredictPlot = np.empty_like(price_jpm)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(y_train_pred)+lookback-1:len(price_jpm)-1, :] = y_test_pred[:, [0]]

original = scaler.inverse_transform(price_jpm['Close'].values.reshape(-1,1))

predictions = np.append(trainPredictPlot, testPredictPlot, axis=1)
predictions = np.append(predictions, original, axis=1)
result = pd.DataFrame(predictions)

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[0],
                    mode='lines',
                    name='Train prediction')))
fig.add_trace(go.Scatter(x=result.index, y=result[1],
                    mode='lines',
                    name='Test prediction'))
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[2],
                    mode='lines',
                    name='Actual Value')))
fig.update_layout(
    xaxis=dict(
        showline=True,
        showgrid=True,
        showticklabels=False,
        linecolor='white',
        linewidth=2
    ),
    yaxis=dict(
        title=dict(
            text='Close (USD)',
            font=dict(
                family='Rockwell',
                size=12,
                color='white',
            )
        ),
        showline=True,
        showgrid=True,
        showticklabels=True,
        linecolor='white',
        linewidth=2,
        ticks='outside',
        tickfont=dict(
            family='Rockwell',
            size=12,
            color='white',
        ),
    ),
    showlegend=True,
    template='plotly_dark'
)
annotations = []
annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                              xanchor='left', yanchor='bottom',
                              text='Amazon Stock Prediction',
                              font=dict(family='Rockwell',
                                        size=26,
                                        color='white'),
                              showarrow=False))
fig.update_layout(annotations=annotations)

fig.show()

# %%
price_netflix = data_netflix[['Close']]
price_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
# dtypes: float64(1)
# memory usage: 19.8 KB

# %%
from sklearn.preprocessing import MinMaxScaler

price_netflix = data_netflix[['Close']].copy()  # Make an explicit copy
scaler = MinMaxScaler(feature_range=(-1, 1))
price_netflix['Close'] = scaler.fit_transform(price_netflix['Close'].values.reshape(-1,1))

# %%
lookback = 20 # choose sequence length
x_train, y_train, x_test, y_test = split_data(price_netflix, lookback)
print('x_train.shape = ',x_train.shape)
print('y_train.shape = ',y_train.shape)
print('x_test.shape = ',x_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# x_train.shape =  (1996, 19, 1)
# y_train.shape =  (1996, 1)
# x_test.shape =  (499, 19, 1)
# y_test.shape =  (499, 1)

# %%
import torch
import torch.nn as nn

x_train = torch.from_numpy(x_train).type(torch.Tensor)
x_test = torch.from_numpy(x_test).type(torch.Tensor)
y_train_lstm = torch.from_numpy(y_train).type(torch.Tensor)
y_test_lstm = torch.from_numpy(y_test).type(torch.Tensor)
y_train_gru = torch.from_numpy(y_train).type(torch.Tensor)
y_test_gru = torch.from_numpy(y_test).type(torch.Tensor)

# %%
model = GRU(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers)
criterion = torch.nn.MSELoss(reduction='mean')
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
hist = np.zeros(num_epochs)
start_time = time.time()
gru = []

for t in range(num_epochs):
    y_train_pred = model(x_train)

    loss = criterion(y_train_pred, y_train_gru)
    print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()

    optimiser.zero_grad()
    loss.backward()
    optimiser.step()

training_time = time.time()-start_time    
print("Training time: {}".format(training_time))
# Out:
# Epoch  0 MSE:  0.2163359373807907
# Epoch  1 MSE:  0.06561935693025589
# Epoch  2 MSE:  0.11608556658029556
# Epoch  3 MSE:  0.06698238104581833
# Epoch  4 MSE:  0.0506562739610672
# Epoch  5 MSE:  0.06462182849645615
# Epoch  6 MSE:  0.06645867973566055
# Epoch  7 MSE:  0.051183730363845825
# Epoch  8 MSE:  0.0329599604010582
# Epoch  9 MSE:  0.027051648125052452
# Epoch  10 MSE:  0.03421839699149132
# Epoch  11 MSE:  0.03211783617734909
# Epoch  12 MSE:  0.01692112162709236
# Epoch  13 MSE:  0.007958016358315945
# Epoch  14 MSE:  0.01187617052346468
# Epoch  15 MSE:  0.014446009881794453
# Epoch  16 MSE:  0.006232712883502245
# Epoch  17 MSE:  0.0014742602361366153
# Epoch  85 MSE:  0.0003217209014110267
# Epoch  86 MSE:  0.0003200997016392648
# Epoch  87 MSE:  0.00031199364457279444
# Epoch  88 MSE:  0.0003103776543866843
# Epoch  89 MSE:  0.000313628843287006
# Epoch  90 MSE:  0.0003116305742878467
# Epoch  91 MSE:  0.00030758290085941553
# Epoch  92 MSE:  0.00030870153568685055
# Epoch  93 MSE:  0.0003102774790022522
# Epoch  94 MSE:  0.00030712276929989457
# Epoch  95 MSE:  0.00030434157815761864
# Epoch  96 MSE:  0.00030503328889608383
# Epoch  97 MSE:  0.00030443494324572384
# Epoch  98 MSE:  0.0003015557595063001
# Epoch  99 MSE:  0.00030079821590334177
# Epoch  100 MSE:  0.00030171757680363953
# Epoch  101 MSE:  0.000300676969345659
# Epoch  102 MSE:  0.00029903778340667486
# Epoch  103 MSE:  0.0002991677902173251
# Epoch  104 MSE:  0.0002990244247484952
# Training time: 31.51356863975525

# %%
predict = pd.DataFrame(scaler.inverse_transform(y_train_pred.detach().numpy()))
original = pd.DataFrame(scaler.inverse_transform(y_train_gru.detach().numpy()))

# %%
import seaborn as sns
sns.set_style("darkgrid")    

fig = plt.figure()
fig.subplots_adjust(hspace=0.2, wspace=0.2)

plt.subplot(1, 2, 1)
ax = sns.lineplot(x = original.index, y = original[0], label="Data", color='royalblue')
ax = sns.lineplot(x = predict.index, y = predict[0], label="Training Prediction (GRU)", color='tomato')
ax.set_title('Google stock price', size = 14, fontweight='bold')
ax.set_xlabel("Days", size = 14)
ax.set_ylabel("Cost (USD)", size = 14)
ax.set_xticklabels('', size=10)


plt.subplot(1, 2, 2)
ax = sns.lineplot(data=hist, color='royalblue')
ax.set_xlabel("Epoch", size = 14)
ax.set_ylabel("Loss", size = 14)
ax.set_title("Training Loss", size = 14, fontweight='bold')
fig.set_figheight(6)
fig.set_figwidth(16)

# %%
import math, time
from sklearn.metrics import mean_squared_error

y_test_pred = model(x_test)

y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
y_train = scaler.inverse_transform(y_train_gru.detach().numpy())
y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy())
y_test = scaler.inverse_transform(y_test_gru.detach().numpy())

trainScore = math.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[:,0], y_test_pred[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
gru.append(trainScore)
gru.append(testScore)
gru.append(training_time)
# Out:
# Train Score: 9.82 RMSE
# Test Score: 32.55 RMSE

# %%
trainPredictPlot = np.empty_like(price_netflix)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[lookback:len(y_train_pred)+lookback, :] = y_train_pred

testPredictPlot = np.empty_like(price_netflix)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(y_train_pred)+lookback-1:len(price_netflix)-1, :] = y_test_pred

original = scaler.inverse_transform(price_netflix['Close'].values.reshape(-1,1))

predictions = np.append(trainPredictPlot, testPredictPlot, axis=1)
predictions = np.append(predictions, original, axis=1)
result = pd.DataFrame(predictions)

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[0],
                    mode='lines',
                    name='Train prediction')))
fig.add_trace(go.Scatter(x=result.index, y=result[1],
                    mode='lines',
                    name='Test prediction'))
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[2],
                    mode='lines',
                    name='Actual Value')))
fig.update_layout(
    xaxis=dict(
        showline=True,
        showgrid=True,
        showticklabels=False,
        linecolor='white',
        linewidth=2
    ),
    yaxis=dict(
    title=dict(
        text='Close (USD)',
        font=dict(
            family='Rockwell',
            size=12,
            color='white',
        )
    ),
    showline=True,
    showgrid=True,
    showticklabels=True,
    linecolor='white',
    linewidth=2,
    ticks='outside',
    tickfont=dict(
        family='Rockwell',
        size=12,
        color='white',
    ),
    
    ),
    showlegend=True,
    template = 'plotly_dark'

)
annotations = []
annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                              xanchor='left', yanchor='bottom',
                              text='Google Stock Result',
                              font=dict(family='Rockwell',
                                        size=26,
                                        color='white'),
                              showarrow=False))
fig.update_layout(annotations=annotations)

fig.show()

# %%
price_apple = data_apple[['Close']]
price_apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
# dtypes: float64(1)
# memory usage: 19.8 KB

# %%
from sklearn.preprocessing import MinMaxScaler

price_apple = data_apple[['Close']].copy()  # Make an explicit copy
scaler = MinMaxScaler(feature_range=(-1, 1))
price_apple['Close'] = scaler.fit_transform(price_apple['Close'].values.reshape(-1,1))

# %%
lookback = 20 # choose sequence length
x_train, y_train, x_test, y_test = split_data(price_apple, lookback)
print('x_train.shape = ',x_train.shape)
print('y_train.shape = ',y_train.shape)
print('x_test.shape = ',x_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# x_train.shape =  (1996, 19, 1)
# y_train.shape =  (1996, 1)
# x_test.shape =  (499, 19, 1)
# y_test.shape =  (499, 1)

# %%
import torch
import torch.nn as nn

x_train = torch.from_numpy(x_train).type(torch.Tensor)
x_test = torch.from_numpy(x_test).type(torch.Tensor)
y_train_gru = torch.from_numpy(y_train).type(torch.Tensor)
y_test_gru = torch.from_numpy(y_test).type(torch.Tensor)

# %%
input_dim = 1
hidden_dim = 32
num_layers = 2
output_dim = 1
num_epochs = 105

# %%
model = GRU(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers)
criterion = torch.nn.MSELoss(reduction='mean')
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
hist = np.zeros(num_epochs)
start_time = time.time()
gru = []

for t in range(num_epochs):
    y_train_pred = model(x_train)

    loss = criterion(y_train_pred, y_train_gru)
    print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()

    optimiser.zero_grad()
    loss.backward()
    optimiser.step()

training_time = time.time()-start_time    
print("Training time: {}".format(training_time))
# Out:
# Epoch  0 MSE:  0.7405096888542175
# Epoch  1 MSE:  0.3944127857685089
# Epoch  2 MSE:  0.1892138570547104
# Epoch  3 MSE:  0.1824350208044052
# Epoch  4 MSE:  0.21136809885501862
# Epoch  5 MSE:  0.14665231108665466
# Epoch  6 MSE:  0.11829495429992676
# Epoch  7 MSE:  0.1272221952676773
# Epoch  8 MSE:  0.13052836060523987
# Epoch  9 MSE:  0.11262217909097672
# Epoch  10 MSE:  0.08276042342185974
# Epoch  11 MSE:  0.059576068073511124
# Epoch  12 MSE:  0.055696986615657806
# Epoch  13 MSE:  0.05735587328672409
# Epoch  14 MSE:  0.04159638658165932
# Epoch  15 MSE:  0.017819590866565704
# Epoch  16 MSE:  0.007105676922947168
# Epoch  17 MSE:  0.011092470958828926
# Epoch  18 MSE:  0.014909565448760986
# Epoch  19 MSE:  0.01052804198116064
# Epoch  20 MSE:  0.007893565110862255
# Epoch  21 MSE:  0.016031667590141296
# Epoch  22 MSE:  0.020770439878106117
# Epoch  23 MSE:  0.013585594482719898
# Epoch  24 MSE:  0.0060110087506473064
# Epoch  25 MSE:  0.004803304094821215
# Epoch  26 MSE:  0.005972083657979965
# Epoch  27 MSE:  0.005181809887290001
# Epoch  28 MSE:  0.002728692488744855
# Epoch  29 MSE:  0.0012752388138324022
# Epoch  30 MSE:  0.002270745811983943
# Epoch  31 MSE:  0.004462288226932287
# Epoch  32 MSE:  0.005535057745873928
# Epoch  33 MSE:  0.004804262425750494
# Epoch  34 MSE:  0.0035652974620461464
# Epoch  35 MSE:  0.003147224662825465
# Epoch  36 MSE:  0.0035037961788475513
# Epoch  37 MSE:  0.003656333778053522
# Epoch  38 MSE:  0.0029489744920283556
# %%
predict = pd.DataFrame(scaler.inverse_transform(y_train_pred.detach().numpy()))
original = pd.DataFrame(scaler.inverse_transform(y_train_gru.detach().numpy()))

# %%
import seaborn as sns
sns.set_style("darkgrid")    

fig = plt.figure()
fig.subplots_adjust(hspace=0.2, wspace=0.2)

plt.subplot(1, 2, 1)
ax = sns.lineplot(x = original.index, y = original[0], label="Data", color='royalblue')
ax = sns.lineplot(x = predict.index, y = predict[0], label="Training Prediction (GRU)", color='tomato')
ax.set_title('IBM stock price', size = 14, fontweight='bold')
ax.set_xlabel("Days", size = 14)
ax.set_ylabel("Cost (USD)", size = 14)
ax.set_xticklabels('', size=10)


plt.subplot(1, 2, 2)
ax = sns.lineplot(data=hist, color='royalblue')
ax.set_xlabel("Epoch", size = 14)
ax.set_ylabel("Loss", size = 14)
ax.set_title("Training Loss", size = 14, fontweight='bold')
fig.set_figheight(6)
fig.set_figwidth(16)

# %%
import math, time
from sklearn.metrics import mean_squared_error

y_test_pred = model(x_test)

y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
y_train = scaler.inverse_transform(y_train_gru.detach().numpy())
y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy())
y_test = scaler.inverse_transform(y_test_gru.detach().numpy())

trainScore = math.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[:,0], y_test_pred[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
gru.append(trainScore)
gru.append(testScore)
gru.append(training_time)
# Out:
# Train Score: 2.19 RMSE
# Test Score: 13.62 RMSE

# %%
trainPredictPlot = np.empty_like(price_apple)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[lookback:len(y_train_pred)+lookback, :] = y_train_pred

# shift test predictions for plotting
testPredictPlot = np.empty_like(price_apple)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(y_train_pred)+lookback-1:len(price_apple)-1, :] = y_test_pred

original = scaler.inverse_transform(price_apple['Close'].values.reshape(-1,1))

predictions = np.append(trainPredictPlot, testPredictPlot, axis=1)
predictions = np.append(predictions, original, axis=1)
result = pd.DataFrame(predictions)

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[0],
                    mode='lines',
                    name='Train prediction')))
fig.add_trace(go.Scatter(x=result.index, y=result[1],
                    mode='lines',
                    name='Test prediction'))
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[2],
                    mode='lines',
                    name='Actual Value')))
fig.update_layout(
    xaxis=dict(
        showline=True,
        showgrid=True,
        showticklabels=False,
        linecolor='white',
        linewidth=2
    ),
    yaxis=dict(
    title=dict(
        text='Close (USD)',
        font=dict(
            family='Rockwell',
            size=12,
            color='white',
        )
    ),
    showline=True,
    showgrid=True,
    showticklabels=True,
    linecolor='white',
    linewidth=2,
    ticks='outside',
    tickfont=dict(
        family='Rockwell',
        size=12,
        color='white',
    ),
),
    showlegend=True,
    template = 'plotly_dark'

)
annotations = []
annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                              xanchor='left', yanchor='bottom',
                              text='IBM Stock Prediction',
                              font=dict(family='Rockwell',
                                        size=26,
                                        color='white'),
                              showarrow=False))
fig.update_layout(annotations=annotations)

fig.show()

# %%
price_tesla = data_tesla[['Close']]
price_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
# dtypes: float64(1)
# memory usage: 19.8 KB

# %%
from sklearn.preprocessing import MinMaxScaler

price_tesla = data_tesla[['Close']].copy()  # Make an explicit copy
scaler = MinMaxScaler(feature_range=(-1, 1))
price_tesla['Close'] = scaler.fit_transform(price_tesla['Close'].values.reshape(-1,1))

# %%
lookback = 20 # choose sequence length
x_train, y_train, x_test, y_test = split_data(price_tesla, lookback)
print('x_train.shape = ',x_train.shape)
print('y_train.shape = ',y_train.shape)
print('x_test.shape = ',x_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# x_train.shape =  (1996, 19, 1)
# y_train.shape =  (1996, 1)
# x_test.shape =  (499, 19, 1)
# y_test.shape =  (499, 1)

# %%
import torch
import torch.nn as nn

x_train = torch.from_numpy(x_train).type(torch.Tensor)
x_test = torch.from_numpy(x_test).type(torch.Tensor)
y_train_gru = torch.from_numpy(y_train).type(torch.Tensor)
y_test_gru = torch.from_numpy(y_test).type(torch.Tensor)

# %%
input_dim = 1
hidden_dim = 32
num_layers = 2
output_dim = 1
num_epochs = 105

# %%
model = GRU(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers)
criterion = torch.nn.MSELoss(reduction='mean')
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
hist = np.zeros(num_epochs)
start_time = time.time()
gru = []

for t in range(num_epochs):
    y_train_pred = model(x_train)

    loss = criterion(y_train_pred, y_train_gru)
    print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()

    optimiser.zero_grad()
    loss.backward()
    optimiser.step()
# Out:
# Epoch  0 MSE:  0.8614658713340759
# Epoch  1 MSE:  0.4063465893268585
# Epoch  2 MSE:  0.14061933755874634
# Epoch  3 MSE:  0.17279446125030518
# Epoch  4 MSE:  0.18109086155891418
# Epoch  5 MSE:  0.09323903173208237
# Epoch  6 MSE:  0.0590747632086277
# Epoch  7 MSE:  0.0657699853181839
# Epoch  8 MSE:  0.06746125966310501
# Epoch  9 MSE:  0.048282377421855927
# Epoch  10 MSE:  0.01916813850402832
# Epoch  11 MSE:  0.0029736037831753492
# Epoch  12 MSE:  0.014393304474651814
# Epoch  13 MSE:  0.031766124069690704
# Epoch  14 MSE:  0.027103740721940994
# Epoch  15 MSE:  0.01288807112723589
# Epoch  16 MSE:  0.008175559341907501
# Epoch  17 MSE:  0.012964309193193913
# Epoch  18 MSE:  0.017318425700068474
# Epoch  19 MSE:  0.015590048395097256
# Epoch  20 MSE:  0.00936004426330328
# Epoch  21 MSE:  0.0037065616343170404
# Epoch  22 MSE:  0.002633564407005906
# Epoch  23 MSE:  0.006012300495058298
# Epoch  24 MSE:  0.009919317439198494
# Epoch  25 MSE:  0.01058276928961277
# Epoch  26 MSE:  0.007912822999060154
# Epoch  27 MSE:  0.004744393285363913
# Epoch  28 MSE:  0.0035068870056420565
# Epoch  29 MSE:  0.004279092885553837
# Epoch  30 MSE:  0.005433481186628342
# Epoch  31 MSE:  0.005416812840849161
# Epoch  32 MSE:  0.003980026114732027
# Epoch  33 MSE:  0.0021885475143790245
# Epoch  34 MSE:  0.0014207354979589581
# Epoch  35 MSE:  0.0021147860679775476
# Epoch  36 MSE:  0.0033412768971174955
# Epoch  37 MSE:  0.0037658470682799816
# Epoch  38 MSE:  0.0030423824209719896
# Epoch  39 MSE:  0.002010773401707411
# Epoch  40 MSE:  0.0016037850873544812
# Epoch  41 MSE:  0.0019025306683033705
# Epoch  42 MSE:  0.0022749409545212984
# Epoch  43 MSE:  0.002160949632525444
# Epoch  44 MSE:  0.0015992693370208144
# Epoch  45 MSE:  0.0010919475462287664
# Epoch  46 MSE:  0.0010539066279307008
# Epoch  47 MSE:  0.001404034555889666
# Epoch  48 MSE:  0.0016925695817917585
# Epoch  49 MSE:  0.0016070929123088717
# Epoch  50 MSE:  0.0012752842158079147
# Epoch  51 MSE:  0.001049134647473693
# Epoch  52 MSE:  0.001089781173504889
# Epoch  53 MSE:  0.0012381208362057805
# Epoch  54 MSE:  0.0012467055348679423
# Epoch  55 MSE:  0.0010612416081130505
# Epoch  56 MSE:  0.0008558701374568045
# Epoch  57 MSE:  0.0008178919670172036
# Epoch  58 MSE:  0.0009353181230835617
# Epoch  59 MSE:  0.0010291404323652387
# Epoch  60 MSE:  0.0009815117809921503
# Epoch  61 MSE:  0.000864697911310941
# Epoch  62 MSE:  0.0008190139196813107
# Epoch  63 MSE:  0.0008690091199241579
# Epoch  64 MSE:  0.0009148679673671722
# Epoch  65 MSE:  0.0008763146470300853
# Epoch  66 MSE:  0.0007886540261097252
# Epoch  67 MSE:  0.000744303164537996
# Epoch  68 MSE:  0.0007724654860794544
# Epoch  69 MSE:  0.0008125738822855055
# Epoch  70 MSE:  0.0008039553067646921
# Epoch  71 MSE:  0.0007618849049322307
# Epoch  72 MSE:  0.0007430443074554205
# Epoch  73 MSE:  0.0007635108777321875
# Epoch  74 MSE:  0.0007842417689971626
# Epoch  75 MSE:  0.0007707019103690982
# Epoch  76 MSE:  0.0007372910622507334
# Epoch  77 MSE:  0.0007217865786515176
# Epoch  78 MSE:  0.0007328770589083433
# Epoch  79 MSE:  0.0007436747546307743
# Epoch  80 MSE:  0.0007341743330471218
# Epoch  81 MSE:  0.0007175773498602211
# Epoch  82 MSE:  0.0007159258821047843
# Epoch  83 MSE:  0.0007271745125763118
# Epoch  84 MSE:  0.0007314482936635613
# Epoch  85 MSE:  0.0007213340722955763
# Epoch  86 MSE:  0.000710062391590327
# Epoch  87 MSE:  0.0007096685003489256
# Epoch  88 MSE:  0.0007144837290979922
# Epoch  89 MSE:  0.0007126522250473499
# Epoch  90 MSE:  0.000704654841683805
# Epoch  91 MSE:  0.0007005833322182298
# Epoch  92 MSE:  0.0007036365568637848
# Epoch  93 MSE:  0.0007064163801260293
# Epoch  94 MSE:  0.0007032856228761375
# Epoch  95 MSE:  0.0006980613106861711
# Epoch  96 MSE:  0.0006966558867134154
# Epoch  97 MSE:  0.0006979748723097146
# Epoch  98 MSE:  0.0006968742236495018
# Epoch  99 MSE:  0.0006927915965206921
# Epoch  100 MSE:  0.0006899802829138935
# Epoch  101 MSE:  0.0006902891327627003
# Epoch  102 MSE:  0.0006907498463988304
# Epoch  103 MSE:  0.0006888624629937112
# Epoch  104 MSE:  0.0006862207083031535

# %%
training_time = time.time()-start_time    
print("Training time: {}".format(training_time))
# Out:
# Training time: 64.51572966575623

# %%
predict = pd.DataFrame(scaler.inverse_transform(y_train_pred.detach().numpy()))
original = pd.DataFrame(scaler.inverse_transform(y_train_gru.detach().numpy()))

# %%
import seaborn as sns
sns.set_style("darkgrid")    

fig = plt.figure()
fig.subplots_adjust(hspace=0.2, wspace=0.2)

plt.subplot(1, 2, 1)
ax = sns.lineplot(x = original.index, y = original[0], label="Data", color='royalblue')
ax = sns.lineplot(x = predict.index, y = predict[0], label="Training Prediction (GRU)", color='tomato')
ax.set_title('Microsoft stock price', size = 14, fontweight='bold')
ax.set_xlabel("Days", size = 14)
ax.set_ylabel("Cost (USD)", size = 14)
ax.set_xticklabels('', size=10)


plt.subplot(1, 2, 2)
ax = sns.lineplot(data=hist, color='royalblue')
ax.set_xlabel("Epoch", size = 14)
ax.set_ylabel("Loss", size = 14)
ax.set_title("Training Loss", size = 14, fontweight='bold')
fig.set_figheight(6)
fig.set_figwidth(16)

# %%
import math, time
from sklearn.metrics import mean_squared_error

# make predictions
y_test_pred = model(x_test)

# invert predictions
y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
y_train = scaler.inverse_transform(y_train_gru.detach().numpy())
y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy())
y_test = scaler.inverse_transform(y_test_gru.detach().numpy())

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[:,0], y_test_pred[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
gru.append(trainScore)
gru.append(testScore)
gru.append(training_time)
# Out:
# Train Score: 6.16 RMSE
# Test Score: 12.08 RMSE

# %%
trainPredictPlot = np.empty_like(price_tesla)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[lookback:len(y_train_pred)+lookback, :] = y_train_pred

# shift test predictions for plotting
testPredictPlot = np.empty_like(price_tesla)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(y_train_pred)+lookback-1:len(price_tesla)-1, :] = y_test_pred

original = scaler.inverse_transform(price_tesla['Close'].values.reshape(-1,1))

predictions = np.append(trainPredictPlot, testPredictPlot, axis=1)
predictions = np.append(predictions, original, axis=1)
result = pd.DataFrame(predictions)

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[0],
                    mode='lines',
                    name='Train prediction')))
fig.add_trace(go.Scatter(x=result.index, y=result[1],
                    mode='lines',
                    name='Test prediction'))
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[2],
                    mode='lines',
                    name='Actual Value')))
fig.update_layout(
    xaxis=dict(
        showline=True,
        showgrid=True,
        showticklabels=False,
        linecolor='white',
        linewidth=2
    ),
    yaxis=dict(
    title=dict(
        text='Close (USD)',
        font=dict(
            family='Rockwell',
            size=12,
            color='white',
        )
    ),
    showline=True,
    showgrid=True,
    showticklabels=True,
    linecolor='white',
    linewidth=2,
    ticks='outside',
    tickfont=dict(
        family='Rockwell',
        size=12,
        color='white',
    ),
     ),
    showlegend=True,
    template = 'plotly_dark'

)



annotations = []
annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                              xanchor='left', yanchor='bottom',
                              text='Microsoft Stock Prediction',
                              font=dict(family='Rockwell',
                                        size=26,
                                        color='white'),
                              showarrow=False))
fig.update_layout(annotations=annotations)

fig.show()
