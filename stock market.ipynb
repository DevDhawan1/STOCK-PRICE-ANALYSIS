# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import pandas_datareader.data as web
import datetime
import yfinance as yf

# %%
start = datetime.datetime(2015, 6, 4)
end = datetime.datetime(2025, 6, 4)

# %%
jpm = yf.download('JPM', start, end)
jpm.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker            JPM        JPM        JPM        JPM       JPM
# Date
# 2015-06-04  50.405933  50.953081  50.162757  50.390732  13863300
# 2015-06-05  51.234253  51.553421  50.922686  51.196260  20801100
# 2015-06-08  50.831482  51.333036  50.770686  51.264640  14558700
# 2015-06-09  51.051880  51.120271  50.512333  50.877094  13263500
# 2015-06-10  51.872593  52.054974  51.272250  51.363438  17478900

# %%
netflix = yf.download('NFLX', start, end)
netflix.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           NFLX       NFLX       NFLX       NFLX      NFLX
# Date
# 2015-06-04  89.348572  89.428574  88.042854  88.378571  10074400
# 2015-06-05  90.459999  90.540001  89.125717  89.214287  11624200
# 2015-06-08  89.604286  90.815712  88.995712  90.714287  11148900
# 2015-06-09  92.449997  92.714287  89.334290  89.334290  22024800
# 2015-06-10  95.871429  98.970001  93.225716  93.395714  57121400

# %%
tesla = yf.download('TSLA', start, end)
tesla.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           TSLA       TSLA       TSLA       TSLA      TSLA
# Date
# 2015-06-04  16.394667  16.620001  16.380667  16.500000  36804000
# 2015-06-05  16.609333  16.646667  16.378668  16.400000  45330000
# 2015-06-08  17.086000  17.250000  16.687332  16.723333  75255000
# 2015-06-09  17.066668  17.182667  16.942667  17.026667  39166500
# 2015-06-10  16.713333  16.933332  16.566668  16.793333  51817500

# %%
apple = yf.download('AAPL', start, end)
apple.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2015-06-04  28.972355  29.245595  28.871570  29.021628  153800400
# 2015-06-05  28.813330  29.046257  28.748381  29.003703  142507200
# 2015-06-08  28.622961  28.938755  28.405713  28.869323  210699200
# 2015-06-09  28.537855  28.685674  28.134716  28.376599  224301600
# 2015-06-10  28.864843  28.967866  28.634156  28.649834  156349200

# %%
jpm.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker          JPM          JPM          JPM          JPM           JPM
# count   2515.000000  2515.000000  2515.000000  2515.000000  2.515000e+03
# mean     113.692716   114.745198   112.589587   113.651704  1.368988e+07
# std       52.053210    52.513933    51.528392    51.989790  6.496789e+06
# min       41.160069    41.811556    38.298212    41.803802  3.220500e+06
# 25%       78.965809    79.839472    78.036836    78.893325  9.347350e+06
# 50%       98.669594   100.008020    97.612010    98.865200  1.228310e+07
# 75%      138.837128   139.961106   137.569524   138.740480  1.596755e+07
# max      278.236206   278.534375   275.522925   276.973965  5.619230e+07

# %%
jpm.columns = jpm.columns.get_level_values(0)

# %%
jpm.isna().sum()
# Out:
# Price
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
jpm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2515 entries, 2015-06-04 to 2025-06-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
#  1   High    2515 non-null   float64
#  2   Low     2515 non-null   float64
#  3   Open    2515 non-null   float64
#  4   Volume  2515 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 117.9 KB

# %%
netflix.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker         NFLX         NFLX         NFLX         NFLX          NFLX
# count   2515.000000  2515.000000  2515.000000  2515.000000  2.515000e+03
# mean     374.882136   380.251678   369.148857   374.686203  8.391980e+06
# std      224.981499   227.531013   222.046284   224.609062  7.421263e+06
# min       82.790001    84.699997    79.949997    80.570000  1.144000e+06
# 25%      187.794998   189.945000   184.665001   187.439995  4.061650e+06
# 50%      348.410004   354.000000   342.440002   348.109985  6.181800e+06
# 75%      501.214996   507.755005   493.895004   501.720001  9.920250e+06
# max     1218.979980  1229.569946  1211.180054  1219.869995  1.333875e+08

# %%
netflix.columns = netflix.columns.get_level_values(0)

# %%
netflix.isna().sum()
# Out:
# Price
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2515 entries, 2015-06-04 to 2025-06-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
#  1   High    2515 non-null   float64
#  2   Low     2515 non-null   float64
#  3   Open    2515 non-null   float64
#  4   Volume  2515 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 117.9 KB

# %%
apple.describe()
apple.columns = apple.columns.get_level_values(0)

# %%
apple.isna().sum()
# Out:
# Price
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2515 entries, 2015-06-04 to 2025-06-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
#  1   High    2515 non-null   float64
#  2   Low     2515 non-null   float64
#  3   Open    2515 non-null   float64
#  4   Volume  2515 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 117.9 KB

# %%
tesla.describe()
tesla.columns = tesla.columns.get_level_values(0)

# %%
tesla.isna().sum()
# Out:
# Price
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2515 entries, 2015-06-04 to 2025-06-03
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
#  1   High    2515 non-null   float64
#  2   Low     2515 non-null   float64
#  3   Open    2515 non-null   float64
#  4   Volume  2515 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 117.9 KB

# %%
fig = px.histogram(jpm, 
                   x='Close', 
                   marginal='box', 
                   nbins=47, 
                   title='Distribution of Close')
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.histogram(jpm, 
                   x='Open', 
                   marginal='box', 
                   color_discrete_sequence=['red'], 
                   title='Distribution of open')
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.scatter(jpm, 
                 x='Open', 
                 y='Close', 
                 
                 opacity=0.8, 
                  
                 title='Open vs. Close')
fig.update_traces(marker_size=5)
fig.show()

# %%
jpm.corr()
# Out:
# Price      Close      High       Low      Open    Volume
# Price
# Close   1.000000  0.999784  0.999766  0.999529 -0.362755
# High    0.999784  1.000000  0.999647  0.999759 -0.355120
# Low     0.999766  0.999647  1.000000  0.999753 -0.369517
# Open    0.999529  0.999759  0.999753  1.000000 -0.361396
# Volume -0.362755 -0.355120 -0.369517 -0.361396  1.000000

# %%
jpm['2015':'2025'].plot(subplots=True, figsize=(10,12))
plt.title('JP Morgan & Chase Co stock attributes from 2015 to 2025')
plt.show()

# %%
netflix['2015':'2025'].plot(subplots=True, figsize=(10,12))
plt.title('Netflix stock attributes from 2015 to 2025')
plt.show()

# %%
tesla['2015':'2025'].plot(subplots=True, figsize=(10,12))
plt.title('Tesla stock attributes from 2015 to 2025')
plt.show()

# %%
apple['2015':'2025'].plot(subplots=True, figsize=(10,12))
plt.title('Apple stock attributes from 2015 to 2025')
plt.show()

# %%
jpm.High.plot()
netflix.High.plot()
tesla.High.plot()
apple.High.plot()
plt.legend(['JP Morgan & Chase Co', 'Netflix', 'Tesla', 'Apple'])
plt.show()

# %%
normalized_jpm = jpm.High.div(jpm.High.iloc[0]).mul(100)
normalized_netflix = netflix.High.div(netflix.High.iloc[0]).mul(100)
normalized_apple = apple.High.div(apple.High.iloc[0]).mul(100)
normalized_tesla = tesla.High.div(tesla.High.iloc[0]).mul(100)
normalized_jpm.plot()
normalized_netflix.plot()
normalized_apple.plot()
normalized_tesla.plot()
plt.legend(['JP Morgan & Chase Co', 'Netflix', 'Tesla', 'Apple'])
plt.show()

# %%
jpm_mean = jpm.High.expanding().mean()
jpm_std = jpm.High.expanding().std()
jpm.High.plot()
jpm_mean.plot()
jpm_std.plot()
plt.legend(['High','Expanding Mean','Expanding Standard Deviation'])
plt.title('JP Morgan & Chase Co')
plt.show()

# %%
netflix_mean = netflix.High.expanding().mean()
netflix_std = netflix.High.expanding().std()
netflix.High.plot()
netflix_mean.plot()
netflix_std.plot()
plt.legend(['High','Expanding Mean','Expanding Standard Deviation'])
plt.title('Netflix')
plt.show()

# %%
apple_mean = apple.High.expanding().mean()
apple_std = apple.High.expanding().std()
apple.High.plot()
apple_mean.plot()
apple_std.plot()
plt.legend(['High','Expanding Mean','Expanding Standard Deviation'])
plt.title('Apple')
plt.show()

# %%
tesla_mean = tesla.High.expanding().mean()
tesla_std = tesla.High.expanding().std()
tesla.High.plot()
tesla_mean.plot()
tesla_std.plot()
plt.legend(['High','Expanding Mean','Expanding Standard Deviation'])
plt.title('Tesla')
plt.show()

# %%
from pylab import rcParams
import statsmodels.api as sm

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_jpm_volume = sm.tsa.seasonal_decompose(jpm["High"],period=360)
figure = decomposed_jpm_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for JPM', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_netflix_volume = sm.tsa.seasonal_decompose(netflix["High"],period=360)
figure = decomposed_netflix_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for Netflix', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_apple_volume = sm.tsa.seasonal_decompose(apple["High"],period=360)
figure = decomposed_apple_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for Apple', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_tesla_volume = sm.tsa.seasonal_decompose(tesla["High"],period=360)
figure = decomposed_tesla_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for Tesla', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_jpm_volume = sm.tsa.seasonal_decompose(jpm["Close"],period=360)
figure = decomposed_jpm_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for JPM', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_netflix_volume = sm.tsa.seasonal_decompose(netflix["Close"],period=360)
figure = decomposed_netflix_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for Netflix', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_apple_volume = sm.tsa.seasonal_decompose(apple["Close"],period=360)
figure = decomposed_apple_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for Apple', fontsize=16, y=1.02)
plt.show()

# %%
rcParams['figure.figsize'] = 11, 9
decomposed_tesla_volume = sm.tsa.seasonal_decompose(tesla["Close"],period=360)
figure = decomposed_tesla_volume.plot()
figure.suptitle('Decomposition for Trend and Seasonality for Tesla', fontsize=16, y=1.02)
plt.show()

# %%
data_jpm = jpm.sort_values(['Date'])
data_jpm.head()
# Out:
# Price           Close       High        Low       Open    Volume
# Date
# 2015-06-04  50.405933  50.953081  50.162757  50.390732  13863300
# 2015-06-05  51.234253  51.553421  50.922686  51.196260  20801100
# 2015-06-08  50.831482  51.333036  50.770686  51.264640  14558700
# 2015-06-09  51.051880  51.120271  50.512333  50.877094  13263500
# 2015-06-10  51.872593  52.054974  51.272250  51.363438  17478900

# %%
jpm_with_date = jpm.reset_index()
print(jpm_with_date.head())
# Out:
# Price       Date      Close       High        Low       Open    Volume
# 0     2015-06-04  50.405933  50.953081  50.162757  50.390732  13863300
# 1     2015-06-05  51.234253  51.553421  50.922686  51.196260  20801100
# 2     2015-06-08  50.831482  51.333036  50.770686  51.264640  14558700
# 3     2015-06-09  51.051880  51.120271  50.512333  50.877094  13263500
# 4     2015-06-10  51.872593  52.054974  51.272250  51.363438  17478900

# %%
data_jpm = jpm_with_date.sort_values(['Date'])
sns.set_style("darkgrid")
plt.figure(figsize = (15,9))
plt.plot(data_jpm[['Close']])
plt.xticks(range(0,data_jpm.shape[0],500),data_jpm['Date'].loc[::500],rotation=45)
plt.title("JPM Stock Price",fontsize=18, fontweight='bold')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price (USD)',fontsize=18)
plt.show()

# %%
netflix_with_date = netflix.reset_index()
data_netflix = netflix_with_date.sort_values(['Date'])
sns.set_style("darkgrid")
plt.figure(figsize = (15,9))
plt.plot(data_netflix[['Close']])
plt.xticks(range(0,data_netflix.shape[0],500),data_netflix['Date'].loc[::500],rotation=45)
plt.title("Netflix Stock Price",fontsize=18, fontweight='bold')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price (USD)',fontsize=18)
plt.show()

# %%
apple_with_date = apple.reset_index()
data_apple = apple_with_date.sort_values(['Date'])
sns.set_style("darkgrid")
plt.figure(figsize = (15,9))
plt.plot(data_apple[['Close']])
plt.xticks(range(0,data_apple.shape[0],500),data_apple['Date'].loc[::500],rotation=45)
plt.title("Apple Stock Price",fontsize=18, fontweight='bold')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price (USD)',fontsize=18)
plt.show()

# %%
tesla_with_data = tesla.reset_index()
data_tesla = tesla_with_data.sort_values(['Date'])
sns.set_style("darkgrid")
plt.figure(figsize = (15,9))
plt.plot(data_tesla[['Close']])
plt.xticks(range(0,data_tesla.shape[0],500),data_tesla['Date'].loc[::500],rotation=45)
plt.title("Tesla Stock Price",fontsize=18, fontweight='bold')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price (USD)',fontsize=18)
plt.show()

# %%
price_jpm = data_jpm[['Close']]
price_jpm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
# dtypes: float64(1)
# memory usage: 19.8 KB

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
price_jpm = data_jpm[['Close']].copy()
scaler = MinMaxScaler(feature_range=(-1,1))
price_jpm['Close'] = scaler.fit_transform(price_jpm['Close'].values.reshape(-1,1))

# %%
def split_data(stock, lookback):
    data_raw = stock.to_numpy()
    data = []

    for index in range(len(data_raw) - lookback):
        data.append(data_raw[index: index + lookback])

    data = np.array(data)
    test_set_size = int(np.round(0.2*data.shape[0]))
    train_set_size = data.shape[0] - (test_set_size)

    x_train = data[:train_set_size,:-1,:]
    y_train = data[:train_set_size,-1,:]

    x_test = data[train_set_size:,:-1]
    y_test = data[train_set_size:,-1,:]

    return [x_train, y_train, x_test, y_test]

# %%
lookback = 20
x_train, y_train, x_test, y_test = split_data(price_jpm, lookback)
print("x_train.shape = ",x_train.shape)
print("x_test.shape= ",x_test.shape)
print("y_train.shape = ",y_train.shape)
print("y_test.shape= ",y_test.shape)
# Out:
# x_train.shape =  (1996, 19, 1)
# x_test.shape=  (499, 19, 1)
# y_train.shape =  (1996, 1)
# y_test.shape=  (499, 1)

# %%
import torch
import torch.nn as nn

# %%
x_train = torch.from_numpy(x_train).type(torch.Tensor)
y_train_gru = torch.from_numpy(y_train).type(torch.Tensor)
x_test = torch.from_numpy(x_test).type(torch.Tensor)
y_test_gru = torch.from_numpy(y_test).type(torch.Tensor)

# %%
input_dim = 1
hidden_dim = 32
num_layers = 2
output_dim = 1
num_epochs = 105

# %%
class GRU(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(GRU, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        
        self.gru = nn.GRU(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()
        out, (hn) = self.gru(x, (h0.detach()))
        out = self.fc(out[:, -1, :]) 
        return out

# %%
model = GRU(input_dim, hidden_dim,output_dim, num_layers)
criterion = torch.nn.MSELoss(reduction='mean')
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
import time
hist = np.zeros(num_epochs)
start_time = time.time()
gru = []

for t in range(num_epochs):
    y_train_pred = model(x_train)

    loss = criterion(y_train_pred, y_train_gru)
    print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()

    optimiser.zero_grad()
    loss.backward()
    optimiser.step()

training_time = time.time()-start_time    
print("Training time: {}".format(training_time))
# Out:
# c:\Users\Devansh Dhawan\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\loss.py:610: UserWarning:
#
# Using a target size (torch.Size([1996, 1])) that is different to the input size (torch.Size([1996, 2])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# Epoch  0 MSE:  0.3661900460720062
# Epoch  1 MSE:  0.23162230849266052
# Epoch  2 MSE:  0.1235230341553688
# Epoch  3 MSE:  0.04980919882655144
# Epoch  4 MSE:  0.04414794221520424
# Epoch  5 MSE:  0.08114749193191528
# Epoch  6 MSE:  0.061290740966796875
# Epoch  7 MSE:  0.03763025254011154
# Epoch  8 MSE:  0.03238489478826523
# Epoch  9 MSE:  0.03726077824831009
# Epoch  10 MSE:  0.04226529225707054
# Epoch  11 MSE:  0.04308396577835083
# Epoch  12 MSE:  0.039599936455488205
# Epoch  13 MSE:  0.033697742968797684
# Epoch  14 MSE:  0.027861803770065308
# Epoch  15 MSE:  0.0241758543998003
# Epoch  16 MSE:  0.023404506966471672
# Epoch  17 MSE:  0.024477515369653702
# Epoch  18 MSE:  0.025135304778814316
# Epoch  19 MSE:  0.023676950484514236
# Epoch  20 MSE:  0.020251965150237083
# Epoch  21 MSE:  0.016468092799186707
# Epoch  22 MSE:  0.013942394405603409
# Epoch  23 MSE:  0.01317413616925478
# Epoch  24 MSE:  0.013433019630610943
# Epoch  25 MSE:  0.013459143228828907
# Epoch  26 MSE:  0.012340342625975609
# Epoch  27 MSE:  0.010023895651102066
# Epoch  28 MSE:  0.007278055883944035
# Epoch  29 MSE:  0.005185360554605722
# Epoch  30 MSE:  0.004382968880236149
# Epoch  31 MSE:  0.004495353903621435
# Epoch  32 MSE:  0.004400441888719797
# Epoch  33 MSE:  0.0033665611408650875
# %%
predict = pd.DataFrame(scaler.inverse_transform(y_train_pred.detach().numpy()))
original = pd.DataFrame(scaler.inverse_transform(y_train_gru.detach().numpy()))

# %%
import seaborn as sns
sns.set_style("darkgrid")    

fig = plt.figure()
fig.subplots_adjust(hspace=0.2, wspace=0.2)

plt.subplot(1, 2, 1)
ax = sns.lineplot(x = original.index, y = original[0], label="Data", color='royalblue')
ax = sns.lineplot(x = predict.index, y = predict[0], label="Training Prediction (GRU)", color='tomato')
ax.set_title('JPM stock price', size = 14, fontweight='bold')
ax.set_xlabel("Days", size = 14)
ax.set_ylabel("Cost (USD)", size = 14)
ax.set_xticklabels('', size=10)


plt.subplot(1, 2, 2)
ax = sns.lineplot(data=hist, color='royalblue')
ax.set_xlabel("Epoch", size = 14)
ax.set_ylabel("Loss", size = 14)
ax.set_title("Training Loss", size = 14, fontweight='bold')
fig.set_figheight(6)
fig.set_figwidth(16)

# %%
import math, time
from sklearn.metrics import mean_squared_error
y_test_pred = model(x_test)

# invert predictions
y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
y_train = scaler.inverse_transform(y_train_gru.detach().numpy())
y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy())
y_test = scaler.inverse_transform(y_test_gru.detach().numpy())

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[:,0], y_test_pred[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
gru.append(trainScore)
gru.append(testScore)
gru.append(training_time)
# Out:
# Train Score: 1.94 RMSE
# Test Score: 7.22 RMSE

# %%
trainPredictPlot = np.empty_like(price_jpm)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[lookback:len(y_train_pred)+lookback, :] = y_train_pred[:, [0]]

testPredictPlot = np.empty_like(price_jpm)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(y_train_pred)+lookback-1:len(price_jpm)-1, :] = y_test_pred[:, [0]]

original = scaler.inverse_transform(price_jpm['Close'].values.reshape(-1,1))

predictions = np.append(trainPredictPlot, testPredictPlot, axis=1)
predictions = np.append(predictions, original, axis=1)
result = pd.DataFrame(predictions)

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[0],
                    mode='lines',
                    name='Train prediction')))
fig.add_trace(go.Scatter(x=result.index, y=result[1],
                    mode='lines',
                    name='Test prediction'))
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[2],
                    mode='lines',
                    name='Actual Value')))
fig.update_layout(
    xaxis=dict(
        showline=True,
        showgrid=True,
        showticklabels=False,
        linecolor='white',
        linewidth=2
    ),
    yaxis=dict(
        title=dict(
            text='Close (USD)',
            font=dict(
                family='Rockwell',
                size=12,
                color='white',
            )
        ),
        showline=True,
        showgrid=True,
        showticklabels=True,
        linecolor='white',
        linewidth=2,
        ticks='outside',
        tickfont=dict(
            family='Rockwell',
            size=12,
            color='white',
        ),
    ),
    showlegend=True,
    template='plotly_dark'
)
annotations = []
annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                              xanchor='left', yanchor='bottom',
                              text='JPM Stock Prediction',
                              font=dict(family='Rockwell',
                                        size=26,
                                        color='white'),
                              showarrow=False))
fig.update_layout(annotations=annotations)

fig.show()

# %%
price_netflix = data_netflix[['Close']]
price_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
# dtypes: float64(1)
# memory usage: 19.8 KB

# %%
from sklearn.preprocessing import MinMaxScaler

price_netflix = data_netflix[['Close']].copy()  # Make an explicit copy
scaler = MinMaxScaler(feature_range=(-1, 1))
price_netflix['Close'] = scaler.fit_transform(price_netflix['Close'].values.reshape(-1,1))

# %%
lookback = 20 # choose sequence length
x_train, y_train, x_test, y_test = split_data(price_netflix, lookback)
print('x_train.shape = ',x_train.shape)
print('y_train.shape = ',y_train.shape)
print('x_test.shape = ',x_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# x_train.shape =  (1996, 19, 1)
# y_train.shape =  (1996, 1)
# x_test.shape =  (499, 19, 1)
# y_test.shape =  (499, 1)

# %%
import torch
import torch.nn as nn

x_train = torch.from_numpy(x_train).type(torch.Tensor)
x_test = torch.from_numpy(x_test).type(torch.Tensor)
y_train_lstm = torch.from_numpy(y_train).type(torch.Tensor)
y_test_lstm = torch.from_numpy(y_test).type(torch.Tensor)
y_train_gru = torch.from_numpy(y_train).type(torch.Tensor)
y_test_gru = torch.from_numpy(y_test).type(torch.Tensor)

# %%
model = GRU(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers)
criterion = torch.nn.MSELoss(reduction='mean')
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
hist = np.zeros(num_epochs)
start_time = time.time()
gru = []

for t in range(num_epochs):
    y_train_pred = model(x_train)

    loss = criterion(y_train_pred, y_train_gru)
    print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()

    optimiser.zero_grad()
    loss.backward()
    optimiser.step()

training_time = time.time()-start_time    
print("Training time: {}".format(training_time))
# Out:
# Epoch  0 MSE:  0.5204017162322998
# Epoch  1 MSE:  0.19582466781139374
# Epoch  2 MSE:  0.05343732610344887
# Epoch  3 MSE:  0.13376200199127197
# Epoch  4 MSE:  0.10918483138084412
# Epoch  5 MSE:  0.054793812334537506
# Epoch  6 MSE:  0.04761948436498642
# Epoch  7 MSE:  0.06299307942390442
# Epoch  8 MSE:  0.07131512463092804
# Epoch  9 MSE:  0.06415237486362457
# Epoch  10 MSE:  0.0466567799448967
# Epoch  11 MSE:  0.029379062354564667
# Epoch  12 MSE:  0.023053113371133804
# Epoch  13 MSE:  0.029925595968961716
# Epoch  14 MSE:  0.03529097139835358
# Epoch  15 MSE:  0.026493920013308525
# Epoch  16 MSE:  0.012564094737172127
# Epoch  17 MSE:  0.006686929147690535
# Epoch  18 MSE:  0.01033360417932272
# Epoch  19 MSE:  0.0150765934959054
# Epoch  20 MSE:  0.012953164055943489
# Epoch  21 MSE:  0.00525888055562973
# Epoch  22 MSE:  0.001355932094156742
# Epoch  23 MSE:  0.006708070635795593
# Epoch  24 MSE:  0.01160534005612135
# Epoch  25 MSE:  0.0076895891688764095
# Epoch  26 MSE:  0.002388525055721402
# Epoch  27 MSE:  0.0022959511261433363
# Epoch  28 MSE:  0.0048941560089588165
# Epoch  29 MSE:  0.005662236828356981
# Epoch  30 MSE:  0.0038330971729010344
# Epoch  31 MSE:  0.001621446805074811
# Epoch  32 MSE:  0.001171893090941012
# Epoch  33 MSE:  0.002507006051018834
# Epoch  34 MSE:  0.003806467866525054
# Epoch  35 MSE:  0.0036178792361170053
# Epoch  36 MSE:  0.0023697183933109045
# Epoch  37 MSE:  0.0014731640694662929
# Epoch  38 MSE:  0.0016021623741835356
# Epoch  39 MSE:  0.002220659051090479
# Epoch  40 MSE:  0.002406938700005412
# Epoch  41 MSE:  0.0018286820268258452
# Epoch  42 MSE:  0.0009958483278751373
# Epoch  43 MSE:  0.000675938674248755
# Epoch  44 MSE:  0.0010383524931967258
# Epoch  45 MSE:  0.0014617963461205363
# Epoch  46 MSE:  0.0013506888644769788
# Epoch  47 MSE:  0.0009038146235980093
# Epoch  48 MSE:  0.0007316094706766307
# Epoch  49 MSE:  0.000978217227384448
# Epoch  50 MSE:  0.0012187586398795247
# Epoch  51 MSE:  0.0010988644789904356
# Epoch  52 MSE:  0.0007599821547046304
# Epoch  53 MSE:  0.0005844241823069751
# Epoch  54 MSE:  0.0006873388774693012
# Epoch  55 MSE:  0.000818821950815618
# Epoch  56 MSE:  0.000752997410017997
# Epoch  57 MSE:  0.0005794033640995622
# Epoch  58 MSE:  0.0005204621702432632
# Epoch  59 MSE:  0.0006152545101940632
# Epoch  60 MSE:  0.0007060686475597322
# Epoch  61 MSE:  0.0006693180184811354
# Epoch  62 MSE:  0.0005580242723226547
# Epoch  63 MSE:  0.0005058563547208905
# Epoch  64 MSE:  0.0005456682993099093
# Epoch  65 MSE:  0.0005810009897686541
# Epoch  66 MSE:  0.0005356594338081777
# Epoch  67 MSE:  0.0004584967391565442
# Epoch  68 MSE:  0.00043883430771529675
# Epoch  69 MSE:  0.00047681410796940327
# Epoch  70 MSE:  0.0004976289928890765
# Epoch  71 MSE:  0.0004664751177188009
# Epoch  72 MSE:  0.0004294358368497342
# Epoch  73 MSE:  0.0004341078456491232
# Epoch  74 MSE:  0.0004587481962516904
# Epoch  75 MSE:  0.0004537379718385637
# Epoch  76 MSE:  0.0004201855044811964
# Epoch  77 MSE:  0.0004005665541626513
# Epoch  78 MSE:  0.00040898192673921585
# Epoch  79 MSE:  0.0004165270656812936
# Epoch  80 MSE:  0.00040264363633468747
# Epoch  81 MSE:  0.0003841454745270312
# Epoch  82 MSE:  0.00038346517249010503
# Epoch  83 MSE:  0.00039346719859167933
# Epoch  84 MSE:  0.0003925184137187898
# Epoch  85 MSE:  0.00037950550904497504
# Epoch  86 MSE:  0.00037167573464103043
# Epoch  87 MSE:  0.0003746844013221562
# Epoch  88 MSE:  0.0003760189574677497
# Epoch  89 MSE:  0.0003678321954794228
# Epoch  90 MSE:  0.00035874577588401735
# Epoch  91 MSE:  0.0003578804316930473
# Epoch  92 MSE:  0.00036037564859725535
# Epoch  93 MSE:  0.0003574495203793049
# Epoch  94 MSE:  0.0003512233088258654
# Epoch  95 MSE:  0.0003492330724839121
# Epoch  96 MSE:  0.00035088651929982007
# Epoch  97 MSE:  0.0003496627614367753
# Epoch  98 MSE:  0.0003448222123552114
# Epoch  99 MSE:  0.00034164992393925786
# Epoch  100 MSE:  0.0003416770196054131
# Epoch  101 MSE:  0.00034085632069036365
# Epoch  102 MSE:  0.0003374909283593297
# Epoch  103 MSE:  0.00033479047124274075
# Epoch  104 MSE:  0.000334547454258427
# Training time: 18.96942448616028

# %%
predict = pd.DataFrame(scaler.inverse_transform(y_train_pred.detach().numpy()))
original = pd.DataFrame(scaler.inverse_transform(y_train_gru.detach().numpy()))

# %%
import seaborn as sns
sns.set_style("darkgrid")    

fig = plt.figure()
fig.subplots_adjust(hspace=0.2, wspace=0.2)

plt.subplot(1, 2, 1)
ax = sns.lineplot(x = original.index, y = original[0], label="Data", color='royalblue')
ax = sns.lineplot(x = predict.index, y = predict[0], label="Training Prediction (GRU)", color='tomato')
ax.set_title('Netflix stock price', size = 14, fontweight='bold')
ax.set_xlabel("Days", size = 14)
ax.set_ylabel("Cost (USD)", size = 14)
ax.set_xticklabels('', size=10)


plt.subplot(1, 2, 2)
ax = sns.lineplot(data=hist, color='royalblue')
ax.set_xlabel("Epoch", size = 14)
ax.set_ylabel("Loss", size = 14)
ax.set_title("Training Loss", size = 14, fontweight='bold')
fig.set_figheight(6)
fig.set_figwidth(16)

# %%
import math, time
from sklearn.metrics import mean_squared_error

y_test_pred = model(x_test)

y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
y_train = scaler.inverse_transform(y_train_gru.detach().numpy())
y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy())
y_test = scaler.inverse_transform(y_test_gru.detach().numpy())

trainScore = math.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[:,0], y_test_pred[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
gru.append(trainScore)
gru.append(testScore)
gru.append(training_time)
# Out:
# Train Score: 10.39 RMSE
# Test Score: 38.04 RMSE

# %%
trainPredictPlot = np.empty_like(price_netflix)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[lookback:len(y_train_pred)+lookback, :] = y_train_pred

testPredictPlot = np.empty_like(price_netflix)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(y_train_pred)+lookback-1:len(price_netflix)-1, :] = y_test_pred

original = scaler.inverse_transform(price_netflix['Close'].values.reshape(-1,1))

predictions = np.append(trainPredictPlot, testPredictPlot, axis=1)
predictions = np.append(predictions, original, axis=1)
result = pd.DataFrame(predictions)

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[0],
                    mode='lines',
                    name='Train prediction')))
fig.add_trace(go.Scatter(x=result.index, y=result[1],
                    mode='lines',
                    name='Test prediction'))
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[2],
                    mode='lines',
                    name='Actual Value')))
fig.update_layout(
    xaxis=dict(
        showline=True,
        showgrid=True,
        showticklabels=False,
        linecolor='white',
        linewidth=2
    ),
    yaxis=dict(
    title=dict(
        text='Close (USD)',
        font=dict(
            family='Rockwell',
            size=12,
            color='white',
        )
    ),
    showline=True,
    showgrid=True,
    showticklabels=True,
    linecolor='white',
    linewidth=2,
    ticks='outside',
    tickfont=dict(
        family='Rockwell',
        size=12,
        color='white',
    ),
    
    ),
    showlegend=True,
    template = 'plotly_dark'

)
annotations = []
annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                              xanchor='left', yanchor='bottom',
                              text='Netflix Stock Result',
                              font=dict(family='Rockwell',
                                        size=26,
                                        color='white'),
                              showarrow=False))
fig.update_layout(annotations=annotations)

fig.show()

# %%
price_apple = data_apple[['Close']]
price_apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
# dtypes: float64(1)
# memory usage: 19.8 KB

# %%
from sklearn.preprocessing import MinMaxScaler

price_apple = data_apple[['Close']].copy()  # Make an explicit copy
scaler = MinMaxScaler(feature_range=(-1, 1))
price_apple['Close'] = scaler.fit_transform(price_apple['Close'].values.reshape(-1,1))

# %%
lookback = 20 # choose sequence length
x_train, y_train, x_test, y_test = split_data(price_apple, lookback)
print('x_train.shape = ',x_train.shape)
print('y_train.shape = ',y_train.shape)
print('x_test.shape = ',x_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# x_train.shape =  (1996, 19, 1)
# y_train.shape =  (1996, 1)
# x_test.shape =  (499, 19, 1)
# y_test.shape =  (499, 1)

# %%
import torch
import torch.nn as nn

x_train = torch.from_numpy(x_train).type(torch.Tensor)
x_test = torch.from_numpy(x_test).type(torch.Tensor)
y_train_gru = torch.from_numpy(y_train).type(torch.Tensor)
y_test_gru = torch.from_numpy(y_test).type(torch.Tensor)

# %%
input_dim = 1
hidden_dim = 32
num_layers = 2
output_dim = 1
num_epochs = 105

# %%
model = GRU(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers)
criterion = torch.nn.MSELoss(reduction='mean')
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
hist = np.zeros(num_epochs)
start_time = time.time()
gru = []

for t in range(num_epochs):
    y_train_pred = model(x_train)

    loss = criterion(y_train_pred, y_train_gru)
    print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()

    optimiser.zero_grad()
    loss.backward()
    optimiser.step()

training_time = time.time()-start_time    
print("Training time: {}".format(training_time))
# Out:
# Epoch  0 MSE:  0.554652988910675
# Epoch  1 MSE:  0.24162377417087555
# Epoch  2 MSE:  0.11095184087753296
# Epoch  3 MSE:  0.1793602555990219
# Epoch  4 MSE:  0.11931861937046051
# Epoch  5 MSE:  0.0666503757238388
# Epoch  6 MSE:  0.07064217329025269
# Epoch  7 MSE:  0.07635970413684845
# Epoch  8 MSE:  0.051560282707214355
# Epoch  9 MSE:  0.014530227519571781
# Epoch  10 MSE:  0.008364378474652767
# Epoch  11 MSE:  0.03448543697595596
# Epoch  12 MSE:  0.024321649223566055
# Epoch  13 MSE:  0.004876952152699232
# Epoch  84 MSE:  0.00030734107713215053
# Epoch  85 MSE:  0.0002973724331241101
# Epoch  86 MSE:  0.0002953120565507561
# Epoch  87 MSE:  0.0002991375222336501
# Epoch  88 MSE:  0.0002982427831739187
# Epoch  89 MSE:  0.0002910424955189228
# Epoch  90 MSE:  0.0002862371038645506
# Epoch  91 MSE:  0.00028828612994402647
# Epoch  92 MSE:  0.0002911961928475648
# Epoch  93 MSE:  0.00028903200291097164
# Epoch  94 MSE:  0.0002846859861165285
# Epoch  95 MSE:  0.0002836537023540586
# Epoch  96 MSE:  0.0002850125019904226
# Epoch  97 MSE:  0.0002841178502421826
# Epoch  98 MSE:  0.00028070996631868184
# Epoch  99 MSE:  0.0002787677804008126
# Epoch  100 MSE:  0.0002796249755192548
# Epoch  101 MSE:  0.0002802665694616735
# Epoch  102 MSE:  0.0002787437988445163
# Epoch  103 MSE:  0.0002769560378510505
# Epoch  104 MSE:  0.00027680426137521863
# Training time: 21.87954616546631

# %%
predict = pd.DataFrame(scaler.inverse_transform(y_train_pred.detach().numpy()))
original = pd.DataFrame(scaler.inverse_transform(y_train_gru.detach().numpy()))

# %%
import seaborn as sns
sns.set_style("darkgrid")    

fig = plt.figure()
fig.subplots_adjust(hspace=0.2, wspace=0.2)

plt.subplot(1, 2, 1)
ax = sns.lineplot(x = original.index, y = original[0], label="Data", color='royalblue')
ax = sns.lineplot(x = predict.index, y = predict[0], label="Training Prediction (GRU)", color='tomato')
ax.set_title('Apple stock price', size = 14, fontweight='bold')
ax.set_xlabel("Days", size = 14)
ax.set_ylabel("Cost (USD)", size = 14)
ax.set_xticklabels('', size=10)


plt.subplot(1, 2, 2)
ax = sns.lineplot(data=hist, color='royalblue')
ax.set_xlabel("Epoch", size = 14)
ax.set_ylabel("Loss", size = 14)
ax.set_title("Training Loss", size = 14, fontweight='bold')
fig.set_figheight(6)
fig.set_figwidth(16)

# %%
import math, time
from sklearn.metrics import mean_squared_error

y_test_pred = model(x_test)

y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
y_train = scaler.inverse_transform(y_train_gru.detach().numpy())
y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy())
y_test = scaler.inverse_transform(y_test_gru.detach().numpy())

trainScore = math.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[:,0], y_test_pred[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
gru.append(trainScore)
gru.append(testScore)
gru.append(training_time)
# Out:
# Train Score: 1.98 RMSE
# Test Score: 9.58 RMSE

# %%
trainPredictPlot = np.empty_like(price_apple)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[lookback:len(y_train_pred)+lookback, :] = y_train_pred

# shift test predictions for plotting
testPredictPlot = np.empty_like(price_apple)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(y_train_pred)+lookback-1:len(price_apple)-1, :] = y_test_pred

original = scaler.inverse_transform(price_apple['Close'].values.reshape(-1,1))

predictions = np.append(trainPredictPlot, testPredictPlot, axis=1)
predictions = np.append(predictions, original, axis=1)
result = pd.DataFrame(predictions)

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[0],
                    mode='lines',
                    name='Train prediction')))
fig.add_trace(go.Scatter(x=result.index, y=result[1],
                    mode='lines',
                    name='Test prediction'))
fig.add_trace(go.Scatter(go.Scatter(x=result.index, y=result[2],
                    mode='lines',
                    name='Actual Value')))
fig.update_layout(
    xaxis=dict(
        showline=True,
        showgrid=True,
        showticklabels=False,
        linecolor='white',
        linewidth=2
    ),
    yaxis=dict(
    title=dict(
        text='Close (USD)',
        font=dict(
            family='Rockwell',
            size=12,
            color='white',
        )
    ),
    showline=True,
    showgrid=True,
    showticklabels=True,
    linecolor='white',
    linewidth=2,
    ticks='outside',
    tickfont=dict(
        family='Rockwell',
        size=12,
        color='white',
    ),
),
    showlegend=True,
    template = 'plotly_dark'

)
annotations = []
annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.05,
                              xanchor='left', yanchor='bottom',
                              text='Apple Stock Prediction',
                              font=dict(family='Rockwell',
                                        size=26,
                                        color='white'),
                              showarrow=False))
fig.update_layout(annotations=annotations)

fig.show()

# %%
price_tesla = data_tesla[['Close']]
price_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
# dtypes: float64(1)
# memory usage: 19.8 KB

# %%
from sklearn.preprocessing import MinMaxScaler

price_tesla = data_tesla[['Close']].copy()  # Make an explicit copy
scaler = MinMaxScaler(feature_range=(-1, 1))
price_tesla['Close'] = scaler.fit_transform(price_tesla['Close'].values.reshape(-1,1))

# %%
lookback = 20 # choose sequence length
x_train, y_train, x_test, y_test = split_data(price_tesla, lookback)
print('x_train.shape = ',x_train.shape)
print('y_train.shape = ',y_train.shape)
print('x_test.shape = ',x_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# x_train.shape =  (1996, 19, 1)
# y_train.shape =  (1996, 1)
# x_test.shape =  (499, 19, 1)
# y_test.shape =  (499, 1)

# %%
import torch
import torch.nn as nn

x_train = torch.from_numpy(x_train).type(torch.Tensor)
x_test = torch.from_numpy(x_test).type(torch.Tensor)
y_train_gru = torch.from_numpy(y_train).type(torch.Tensor)
y_test_gru = torch.from_numpy(y_test).type(torch.Tensor)

# %%
input_dim = 1
hidden_dim = 32
num_layers = 2
output_dim = 1
num_epochs = 105

# %%
model = GRU(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers)
criterion = torch.nn.MSELoss(reduction='mean')
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
hist = np.zeros(num_epochs)
start_time = time.time()
gru = []

for t in range(num_epochs):
    y_train_pred = model(x_train)

    loss = criterion(y_train_pred, y_train_gru)
    print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()

    optimiser.zero_grad()
    loss.backward()
    optimiser.step()

training_time = time.time()-start_time    
print("Training time: {}".format(training_time))
# Out:
# Epoch  0 MSE:  0.0007348447106778622
# Epoch  1 MSE:  0.0007353593246079981
# Epoch  2 MSE:  0.0007339621661230922
# Epoch  3 MSE:  0.0007309883367270231
# Epoch  4 MSE:  0.0007291588117368519
# Epoch  5 MSE:  0.0007288699271157384
# Epoch  6 MSE:  0.0007280576974153519
# Epoch  7 MSE:  0.0007259323610924184
# Epoch  8 MSE:  0.0007240117411129177
# Epoch  9 MSE:  0.0007233081851154566
# Epoch  10 MSE:  0.0007227571913972497
# Epoch  11 MSE:  0.0007212513010017574
# Epoch  12 MSE:  0.0007194179925136268
# Epoch  13 MSE:  0.0007182726985774934
# Epoch  14 MSE:  0.0007175153587013483
# Epoch  15 MSE:  0.000716285954695195
# Epoch  16 MSE:  0.0007146739517338574
# Epoch  17 MSE:  0.0007134060724638402
# Epoch  18 MSE:  0.0007125476258806884
# Epoch  19 MSE:  0.0007115001790225506
# Epoch  20 MSE:  0.0007100801449269056
# Epoch  21 MSE:  0.0007087306585162878
# Epoch  22 MSE:  0.0007076815236359835
# Epoch  23 MSE:  0.0007066244725137949
# Epoch  24 MSE:  0.0007053290028125048
# Epoch  25 MSE:  0.0007040155469439924
# Epoch  26 MSE:  0.0007029148982837796
# Epoch  27 MSE:  0.0007018824690021574
# Epoch  28 MSE:  0.0007006983505561948
# Epoch  29 MSE:  0.000699439668096602
# Epoch  30 MSE:  0.0006982998456805944
# Epoch  31 MSE:  0.0006972505943849683
# Epoch  32 MSE:  0.00069613748928532
# Epoch  33 MSE:  0.0006949681555852294
# Epoch  34 MSE:  0.0006938745500519872
# Epoch  35 MSE:  0.0006928685470484197
# Epoch  36 MSE:  0.0006918408907949924
# Epoch  37 MSE:  0.0006907648057676852
# Epoch  38 MSE:  0.0006897253333590925
# Epoch  39 MSE:  0.0006887533818371594
# Epoch  40 MSE:  0.0006877842242829502
